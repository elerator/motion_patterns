# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
from split_slow_waves import *

# %%
vector1 = np.load("test_data/runstart16_X1_mean.npy")

# %%
vector2 = np.load("test_data/runstart16_X2_mean.npy")

# %%
plt.plot(vector1)
plt.plot(where_slow_wave(vector1))

# %%
plt.plot(vector1)
plt.plot(where_slow_wave(vector1))

# %%
plt.plot(where_slow_wave(vector2))
plt.plot(vector2)

# %%
plt.plot(where_slow_wave(vector2, percentile=30, erosion = 10, dilation = 0))
plt.plot(vector2)
