# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

fs = 100  # Sampling frequency
# Generate the time vector properly
t = np.arange(100) / fs
signala = np.sin(2*np.pi*10*t) # with frequency of 100
plt.plot(t, signala, label='a')

signalb = np.sin(2*np.pi*3*t) # frequency 20
plt.plot(t, signalb, label='b')

signalc = signala + signalb
plt.plot(t, signalc, label='c')

# %%
fc = 30  # Cut-off frequency of the filter
w = fc / (fs / 2) # Normalize the frequency
b, a = signal.butter(5, w, 'low')
output = signal.filtfilt(b, a, signalc)
plt.plot(t[:100], output, label='filtered')
plt.legend()
plt.show()

# %%
t = np.linspace(0, 1, 1000, False)  # 1 second
sig = np.sin(2*np.pi*10*t) + np.sin(2*np.pi*20*t)
fig, (ax1, ax2) = plt.subplots(2, 1, sharex=True)
ax1.plot(t, sig)
ax1.set_title('10 Hz and 20 Hz sinusoids')
ax1.axis([0, 1, -2, 2])


sos = signal.butter(10, 15, 'hp', fs=1000, output='sos')
filtered = signal.sosfilt(sos, sig)
ax2.plot(t, filtered)
ax2.set_title('After 15 Hz high-pass filter')
ax2.axis([0, 1, -2, 2])
ax2.set_xlabel('Time [seconds]')
plt.tight_layout()
plt.show()

# %%
ls
# Out:
# 10_bins_expected_images_interpolated_median.npy*
# 10_bins_expected_images_polynomial.npy*
# 25_bins_expected_images.npy*
# 5_bins_expected_images_interpolated.npy*
# __pycache__/
# anim.html*
# anim_side_by_side.html*
# anim_side_by_side.js*
# arrows.pkl*
# bloodflow.npy*
# butterworth_filter.ipynb*
# cluster_tracking/
# contrast_to_expected_image.ipynb*
# contrast_to_median_expected_image.ipynb*
# contrast_to_median_expected_image.ipynb.invalid*
# detecting_slow_wave_onset.ipynb*
# expected_images.npy*
# explorative_preprocessing_v0.1.ipynb*
# explorative_preprocessing_v0.2_PCA.ipynb*
# explorative_preprocessing_v0.2_fourier.ipynb*
# explorative_preprocessing_v0.3_contrast_to_expected_image.ipynb*
# explorative_preprocessing_v1.ipynb*
# interpolate_vessels.ipynb*
# level_sets-Copy1.ipynb*
# level_sets.ipynb*
# level_sets.ipynb.invalid*
# level_sets_and_expected_flow1.ipynb*
# level_sets_and_expected_flow2.ipynb*
# mask.png*
# mean_across_slow_waves_as_function_of_total_activation.ipynb*
# median_across_slow_waves_as_function_of_total_activation.ipynb*
# notebook_template.ipynb*
# roi.npy*
# roi_background.npy*
# runstart16_X1.npy*
# test_vector_field.npy*
# towards_automatic_tests.ipynb*
# tracking.html*
# vessels_interpolated.npy*
